# %% [markdown]
# # **1. EDA**
# Performing initial investigations on the transformed data so as to discover patterns, to spot anomalies, to test hypothesis and to check assumptions with the help of summary statistics and graphical representations.

# %% [markdown]
# # **2. Initialization**
# Here is where you load all the dependencies required for the good execution of (most of) the notebook. Here is where you load your libraries and instantiate your functions/classes. Here is where you load the data/models/pipelines that are going to be used in the notebook.

# %% [markdown]
# ## **2.1 Loading libraries**

# %%
import pandas as pd


import time, datetime

# %% [markdown]
# ## **2.2 Loading data**

# %%
df = pd.read_csv('BPI_Challenge_2012-training.csv')
test = pd.read_csv('BPI_Challenge_2012-test.csv')

# %% [markdown]
# # **3. EDA**
# The main part of the topics depend a lot on what are the objectives of the notebook, and should be customized for each analysis. It is a good practice to write the analysis of the results obtained in each individual experiment (if any).

# %% [markdown]
# ## **3.1 Distributions**

# %%
df = df.sort_values(by=['case concept:name', 'event time:timestamp']) 

df.head(50)
# Out:
#          eventID   case concept:name            case REG_DATE  \
# 0               0             173688  01-10-2011 00:38:44.546
# 1               1             173688  01-10-2011 00:38:44.546
# 2               2             173688  01-10-2011 00:38:44.546
# 3               3             173688  01-10-2011 00:38:44.546
# 89              4             173688  01-10-2011 00:38:44.546
# 94              5             173688  01-10-2011 00:38:44.546
# 98              7             173688  01-10-2011 00:38:44.546
# 99              6             173688  01-10-2011 00:38:44.546
# 100             8             173688  01-10-2011 00:38:44.546
# 101             9             173688  01-10-2011 00:38:44.546
# 102            10             173688  01-10-2011 00:38:44.546
# 103            11             173688  01-10-2011 00:38:44.546
# 117            12             173688  01-10-2011 00:38:44.546
# 118            13             173688  01-10-2011 00:38:44.546
# 7544           14             173688  01-10-2011 00:38:44.546
# 7548           15             173688  01-10-2011 00:38:44.546
# 8237           16             173688  01-10-2011 00:38:44.546
# 8238           17             173688  01-10-2011 00:38:44.546
# 8239           18             173688  01-10-2011 00:38:44.546
# 8240           19             173688  01-10-2011 00:38:44.546
# 12358          20             173688  01-10-2011 00:38:44.546
# 12413          23             173688  01-10-2011 00:38:44.546
# 12414          21             173688  01-10-2011 00:38:44.546
# 12415          22             173688  01-10-2011 00:38:44.546
# 12416          24             173688  01-10-2011 00:38:44.546
# 12417          25             173688  01-10-2011 00:38:44.546
# 4      4294967296             173691  01-10-2011 08:08:58.256
# 5      4294967297             173691  01-10-2011 08:08:58.256
# 6      4294967298             173691  01-10-2011 08:08:58.256
# 7      4294967299             173691  01-10-2011 08:08:58.256
# 90     4294967300             173691  01-10-2011 08:08:58.256
# 96     4294967301             173691  01-10-2011 08:08:58.256
# 170    4294967302             173691  01-10-2011 08:08:58.256
# 171    4294967303             173691  01-10-2011 08:08:58.256
# 172    4294967305             173691  01-10-2011 08:08:58.256
# 173    4294967304             173691  01-10-2011 08:08:58.256
# 174    4294967306             173691  01-10-2011 08:08:58.256
# 175    4294967307             173691  01-10-2011 08:08:58.256
# 176    4294967308             173691  01-10-2011 08:08:58.256
# 177    4294967309             173691  01-10-2011 08:08:58.256
# 178    4294967310             173691  01-10-2011 08:08:58.256
# 179    4294967311             173691  01-10-2011 08:08:58.256
# 1524   4294967312             173691  01-10-2011 08:08:58.256
# 1525   4294967314             173691  01-10-2011 08:08:58.256
# 1526   4294967313             173691  01-10-2011 08:08:58.256
# 1527   4294967315             173691  01-10-2011 08:08:58.256
# 1528   4294967316             173691  01-10-2011 08:08:58.256
# 1529   4294967317             173691  01-10-2011 08:08:58.256
# 1530   4294967318             173691  01-10-2011 08:08:58.256
# 1531   4294967319             173691  01-10-2011 08:08:58.256
#
#        case AMOUNT_REQ  event org:resource      event concept:name  \
# 0                20000               112.0             A_SUBMITTED
# 1                20000               112.0       A_PARTLYSUBMITTED
# 2                20000               112.0           A_PREACCEPTED
# 3                20000               112.0  W_Completeren aanvraag
# 89               20000                 NaN  W_Completeren aanvraag
# 94               20000             10862.0              A_ACCEPTED
# 98               20000             10862.0             A_FINALIZED
# 99               20000             10862.0              O_SELECTED
# 100              20000             10862.0               O_CREATED
# 101              20000             10862.0                  O_SENT
# 102              20000                 NaN     W_Nabellen offertes
# 103              20000                 NaN  W_Completeren aanvraag
# 117              20000                 NaN     W_Nabellen offertes
# 118              20000                 NaN     W_Nabellen offertes
# 7544             20000             10913.0     W_Nabellen offertes
# 7548             20000             10913.0     W_Nabellen offertes
# 8237             20000             11049.0     W_Nabellen offertes
# 8238             20000             11049.0             O_SENT_BACK
# 8239             20000             11049.0    W_Valideren aanvraag
# 8240             20000             11049.0     W_Nabellen offertes
# 12358            20000             10629.0    W_Valideren aanvraag
# 12413            20000             10629.0              O_ACCEPTED
# 12414            20000             10629.0            A_REGISTERED
# 12415            20000             10629.0              A_APPROVED
# 12416            20000             10629.0             A_ACTIVATED
# 12417            20000             10629.0    W_Valideren aanvraag
# 4                 5000               112.0             A_SUBMITTED
# 5                 5000               112.0       A_PARTLYSUBMITTED
# 6                 5000               112.0           A_PREACCEPTED
# 7                 5000               112.0  W_Completeren aanvraag
# 90                5000                 NaN  W_Completeren aanvraag
# 96                5000                 NaN  W_Completeren aanvraag
# 170               5000                 NaN  W_Completeren aanvraag
# 171               5000             10862.0              A_ACCEPTED
# 172               5000             10862.0              O_SELECTED
# 173               5000             10862.0             A_FINALIZED
# 174               5000             10862.0               O_CREATED
# 175               5000             10862.0                  O_SENT
# 176               5000                 NaN     W_Nabellen offertes
# 177               5000                 NaN  W_Completeren aanvraag
# 178               5000                 NaN     W_Nabellen offertes
# 1524                       START  03-10-2011 16:54:43.257
# 1525                    COMPLETE  03-10-2011 16:56:17.731
# 1526                    COMPLETE  03-10-2011 16:56:17.731
# 1527                    COMPLETE  03-10-2011 16:56:19.613
# 1528                    COMPLETE  03-10-2011 16:56:19.645
# 1529                    SCHEDULE  03-10-2011 16:56:19.941
# 1530                    COMPLETE  03-10-2011 16:56:21.195
# 1531                       START  03-10-2011 16:56:34.792

# %%
df.dtypes #Datatypes per column
# Out:
# eventID                         int64
# case concept:name               int64
# case REG_DATE                  object
# case AMOUNT_REQ                 int64
# event org:resource            float64
# event concept:name             object
# event lifecycle:transition     object
# event time:timestamp           object
# dtype: object

# %%
#See how many NaN values per feature
df.isna().sum()
# Out:
# eventID                           0
# case concept:name                 0
# case REG_DATE                     0
# case AMOUNT_REQ                   0
# event org:resource            17838
# event concept:name                0
# event lifecycle:transition        0
# event time:timestamp              0
# dtype: int64

# %%
#Distribution per type of event
df.groupby(['event concept:name'])['event concept:name'].count().sort_values(ascending=False)
# Out:
# event concept:name
# W_Completeren aanvraag            49310
# W_Nabellen offertes               46628
# W_Nabellen incomplete dossiers    22447
# W_Valideren aanvraag              19145
# W_Afhandelen leads                15953
# A_PARTLYSUBMITTED                 12478
# A_SUBMITTED                       12478
# A_DECLINED                         7590
# A_PREACCEPTED                      6758
# O_CREATED                          6270
# O_SELECTED                         6270
# O_SENT                             6270
# A_ACCEPTED                         4583
# A_FINALIZED                        4487
# O_CANCELLED                        3346
# O_SENT_BACK                        3167
# A_CANCELLED                        2691
# A_ACTIVATED                        2126
# A_REGISTERED                       2126
# A_APPROVED                         2126
# O_ACCEPTED                         2123
# O_DECLINED                          760
# W_Beoordelen fraude                 642
# W_Wijzigen contractgegevens          12
# Name: event concept:name, dtype: int64

# %%
#Distribution per status of event
print(df.groupby(['event lifecycle:transition'])['event lifecycle:transition'].count().sort_values(ascending=False) )
df.groupby(['event lifecycle:transition'])['event lifecycle:transition'].hist()
# Out:
# event lifecycle:transition
# COMPLETE    151130
# START        64510
# SCHEDULE     24146
# Name: event lifecycle:transition, dtype: int64
# event lifecycle:transition
# COMPLETE    AxesSubplot(0.125,0.125;0.775x0.755)
# SCHEDULE    AxesSubplot(0.125,0.125;0.775x0.755)
# START       AxesSubplot(0.125,0.125;0.775x0.755)
# Name: event lifecycle:transition, dtype: object

# %% [markdown]
# ### **3.1.1 Results**
# - Event_ID is unnecessary, given it is unique per event and not important for sequence creation.
# - case REG_DATE is a string --> Conversion to datetime could be nice
# - event time:timestamp is a string --> Conversion to datetime could be nice
# - event org:resource has NaN values (17838 tuples)

# %% [markdown]
# # **4 Results (if any)**
# Here is where you summarize all the results of the analysis as a whole.
